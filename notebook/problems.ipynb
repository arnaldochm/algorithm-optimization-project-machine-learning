# %% [markdown]
# # Optimization of Algorithms problems

# %% [markdown]
# ## Exercise 1: Optimization of a library management system
#
# You are provided with a code that simulates a library management system. The system has the ability to add books to the library, lend books to readers, and receive books back. In addition, it can also list all the books available in the library.
#
# The problem is that the system is very slow and needs to be optimized. Your task is to analyze the code, identify areas of improvement and rewrite parts of the code to make it more efficient. Specifically, you are asked to perform the following improvements (update the below code and implement the following points):
#
# 1. Identify and improve the data structures used to store books in the library and borrowed books. *Hint: Use an `set` instead of a `list` to store books in `Library.books` and `Library.borrowed_books` to make it more efficient to check if a book is present.**
#
# 2. Avoid errors that could occur when attempting to borrow or return a book that is not present. *Hint: Use the `set.discard()` method instead of `list.remove()` in `Library.borrow_book()` and `Library.return_book()` to avoid errors if the book is not present.*
#
# 3. Improve the efficiency of selecting a random book to lend or return. *Hint: Instead of selecting a random book from `Library.books` or `Library.borrowed_books` by indexing (which involves a conversion to list which is expensive), you can convert these sets to lists only once before the cycle.*
#
# 4. Improve the efficiency of the function that lists all the books available in the library. *Hint: Instead of printing each book one by one in `Library.list_books()`, you can construct a complete string with all book titles and then print that string once.*
#
# 5. Avoid repeated calls to `len()` in the body of loops.
#
# 6. Use list comprehension to improve efficiency of book creation.. *Hint: Use list comprehension for book creation, which can be faster than using a for loop and repeatedly calling `Library.add_book()`.*
#
# 7. Optimize checking the availability of borrowed books before attempting to return them. *Hint: Avoid checking `if library.borrowed_books:` before attempting to return a book. If you use sets and the `discard()` method, there is no need for this check.*

# %% [markdown]
# #### Read and update the following given code:

# %%
import random
import time

class Book:
    def __init__(self, title, author, pages):
        self.title = title
        self.author = author
        self.pages = pages

class Library:
    def __init__(self, name):
        self.name = name
        self.books = set()
        self.borrowed_books = set()

    def add_book(self, book):
        if book not in self.books:
            self.books.add(book)
            return True
        return False

    def borrow_book(self, book):
        if book in self.books:
            self.books.discard(book)
            self.borrowed_books.add(book)
            return True
        return False

    def return_book(self, book):
        self.borrowed_books.discard(book)
        self.books.add(book)
        return True

    def list_books(self):
        books = ""
        books = books.join(book.title + '\n' for book in self.books)
        
        print(books)

# Create a library
library = Library("Codeville")

# Add some books
library.books = {Book(f"Book {i}", f"Author {i}", i*10) for i in range(1, 101)}

# Borrow some books
library_books_list = list(library.books)
books_len = len(library_books_list)
for _ in range(50):
    book_to_borrow = library_books_list[random.randint(0, books_len - 1)]
    library.borrow_book(book_to_borrow)

# Return some books
library_borrowed_books_list = list(library.borrowed_books)
borrowed_books_len = len(library_borrowed_books_list)
for _ in range(25):
    if library.borrowed_books:
        book_to_return = library_borrowed_books_list[random.randint(0, borrowed_books_len - 1)]
        library.return_book(book_to_return)

# List all the books
start_time = time.time()
library.list_books()
end_time = time.time()

print(f"Listing took {end_time - start_time} seconds")
# Out:
# Book 14
# Book 80
# Book 21
# Book 91
# Book 89
# Book 65
# Book 79
# Book 67
# Book 27
# Book 83
# Book 69
# Book 84
# Book 17
# Book 49
# Book 66
# Book 31
# Book 36
# Book 81
# Book 86
# Book 5
# Book 85
# Book 62
# Book 54
# Book 46
# Book 6
# Book 25
# Book 32
# Book 29
# Book 23
# Book 51
# Book 90
# Book 58
# Book 55
# Book 1
# Book 13
# Book 50
# Book 42
# Book 3
# Book 39
# Book 30
# Book 52
# Book 92
# Book 37
# Book 53
# Book 38
# Book 78
# Book 11
# Book 28
# Book 34
# Book 64
# Book 8
# Book 76
# Book 56
# Book 7
# Book 73
# Book 77
# Book 60
# Book 9
# Book 41
# Book 44
# Book 15
# Book 16
# Book 82
# Book 57
# Book 22
# Book 26
# Book 94
# Book 95
# Book 75
# Book 70
# Book 96
# Book 19
# Book 20
# Book 97
# Book 68
# Book 18
# Book 35
# Book 40
# Book 98
# Book 71
# Book 99
# Book 72
# Book 33
# Book 24
#
# Listing took 0.0003447532653808594 seconds

# %% [markdown]
# ## Exercise 2: Task Management System Optimization
#
# You are provided with code that simulates a task management system. The system has the ability to add tasks, mark tasks as completed and list all tasks along with their status.
#
# As in the first exercise, the system is quite slow and needs to be optimized. Your task is to analyze the code, identify areas that could be improved, and rewrite parts of the code to make it more efficient. Specifically, you are asked to perform the following tasks:
#
# 1. Identify and improve the data structures used to store the tasks. *Hint: Use an `set` or `dict` instead of a `list` to store tasks in `TaskManager`, to make checking for the existence of a task more efficient.*
#
# 2. Avoid checking whether a task is in the task list each time a task is completed. *Hint: Avoid checking for the existence of a task in `TaskManager.complete_task()`. If you are sure that the task comes from `TaskManager.tasks`, it is not necessary to check if it is in the list.*
#
# 3. Restructure the way task status is tracked. *Hint: Instead of marking a task as completed by modifying its `is_done` attribute, you may consider having two sets or lists in `TaskManager`: one for pending tasks and one for completed tasks.*
#
# 4. Use list comprehension to improve the efficiency of task creation. *Hint: Use a list comprehension for task creation, which may be faster than using a for loop and repeatedly calling `TaskManager.add_task()`.*
#
# 5. Improve the efficiency of the function that lists all tasks. *Hint: Instead of printing each task one by one in `TaskManager.list_tasks()`, you can build a complete string with all tasks and then print that string once.*
#
# 6. Introduce an `id` attribute to uniquely identify each task. *Hint: Consider using an `id` attribute on the `Task` class to uniquely identify each task. This can make it easier to find and manage tasks.*
#
# 7. Avoid repeated calls to the same function or method in a loop. *Hint: Avoid repeatedly calling the same function or method in a loop, such as `TaskManager.add_task()` or `TaskManager.complete_task()`.*
#
# 8. Avoid repetition of code when calculating the status of a task. *Hint: Avoid code repetition. In `TaskManager.list_tasks()`, the task status is calculated the same way for each task. You may consider adding a method to the `Task` class that returns the status as a string.*
#
# 9. Improve code readability by using descriptive variable names. *Hint: Improve code readability by using descriptive variable names.*
#
# 10. Changes the way tasks are iterated over. *Hint: Instead of looping over a range of numbers and then indexing the list of tasks, you can iterate directly over the tasks.*

# %% [markdown]
# #### Read and update the following given code:

# %%
class Task:
    def __init__(self, id, description):
        self.id = id
        self.description = description
        self.is_done = False

    def mark_as_done(self):
        self.is_done = True
    
    def status(self):
        if self.is_done:
            return "completed"
        else:
            return "pending"

class TaskManager:
    def __init__(self):
        self.pending_tasks = {}
        self.completed_tasks = {}

    def add_task(self, task):
        self.pending_tasks[task.id] = task

    def complete_task(self, id):
        if id in self.pending_tasks:
            task = self.pending_tasks.pop(id)
            task.is_done = True
            self.completed_tasks[task.id] = task
        return True

    def list_tasks(self):
        print(self.pending_tasks)
        pending_tasks_desc = "".join(f" Task: {task.description}, Status: {task.status()} \n " for task in self.pending_tasks.values())
        completed_tasks_desc = "".join(f" Task: {task.description}, Status: {task.status()} \n " for task in self.completed_tasks.values())
        print(pending_tasks_desc + completed_tasks_desc)

            
start_time = time.time()
# Create a TaskManager
manager = TaskManager()

# Add some tasks
manager.pending_tasks = {i: Task(i, f"Task {i}") for i in range(1, 1001)}

# Complete some tasks
for i in range(1, 501):
    manager.complete_task(i)

# List all the tasks
manager.list_tasks()

end_time = time.time()

print(f"Entire process took {end_time - start_time} seconds")
# Out:
# {501: <__main__.Task object at 0x7fac52550730>, 502: <__main__.Task object at 0x7fac52550790>, 503: <__main__.Task object at 0x7fac525507f0>, 504: <__main__.Task object at 0x7fac52550850>, 505: <__main__.Task object at 0x7fac525508b0>, 506: <__main__.Task object at 0x7fac52550910>, 507: <__main__.Task object at 0x7fac52550970>, 508: <__main__.Task object at 0x7fac525509d0>, 509: <__main__.Task object at 0x7fac52550a30>, 510: <__main__.Task object at 0x7fac52550a90>, 511: <__main__.Task object at 0x7fac52550af0>, 512: <__main__.Task object at 0x7fac52550b50>, 513: <__main__.Task object at 0x7fac52550bb0>, 514: <__main__.Task object at 0x7fac52550c10>, 515: <__main__.Task object at 0x7fac52550c70>, 516: <__main__.Task object at 0x7fac52550cd0>, 517: <__main__.Task object at 0x7fac52550d30>, 518: <__main__.Task object at 0x7fac52550d90>, 519: <__main__.Task object at 0x7fac52550df0>, 520: <__main__.Task object at 0x7fac52550e50>, 521: <__main__.Task object at 0x7fac52550eb0>, 522: <__main__.Task object at 0x7fac52551930>, 523: <__main__.Task object at 0x7fac52551b10>, 524: <__main__.Task object at 0x7fac52552860>, 525: <__main__.Task object at 0x7fac52553910>, 526: <__main__.Task object at 0x7fac525511b0>, 527: <__main__.Task object at 0x7fac52551210>, 528: <__main__.Task object at 0x7fac52551d50>, 529: <__main__.Task object at 0x7fac52551300>, 530: <__main__.Task object at 0x7fac52553dc0>, 531: <__main__.Task object at 0x7fac52553e20>, 532: <__main__.Task object at 0x7fac52552590>, 533: <__main__.Task object at 0x7fac52552680>, 534: <__main__.Task object at 0x7fac52552530>, 535: <__main__.Task object at 0x7fac52552650>, 536: <__main__.Task object at 0x7fac525529e0>, 537: <__main__.Task object at 0x7fac52553b80>, 538: <__main__.Task object at 0x7fac52553a30>, 539: <__main__.Task object at 0x7fac525521a0>, 540: <__main__.Task object at 0x7fac52552080>, 541: <__main__.Task object at 0x7fac52551ff0>, 542: <__main__.Task object at 0x7fac52551ed0>, 543: <__main__.Task object at 0x7fac52551f30>, 544: <__main__.Task object at 0x7fac52551f60>, 545: <__main__.Task object at 0x7fac525534c0>, 546: <__main__.Task object at 0x7fac52551f00>, 547: <__main__.Task object at 0x7fac52551e10>, 548: <__main__.Task object at 0x7fac52553e50>, 549: <__main__.Task object at 0x7fac525522c0>, 550: <__main__.Task object at 0x7fac525524a0>, 551: <__main__.Task object at 0x7fac52552950>, 552: <__main__.Task object at 0x7fac525528f0>, 553: <__main__.Task object at 0x7fac52552500>, 554: <__main__.Task object at 0x7fac52552410>, 555: <__main__.Task object at 0x7fac525514e0>, 556: <__main__.Task object at 0x7fac525516f0>, 557: <__main__.Task object at 0x7fac525518a0>, 558: <__main__.Task object at 0x7fac52551810>, 559: <__main__.Task object at 0x7fac52551960>, 560: <__main__.Task object at 0x7fac52553430>, 561: <__main__.Task object at 0x7fac52553bb0>, 562: <__main__.Task object at 0x7fac52553520>, 563: <__main__.Task object at 0x7fac52553940>, 564: <__main__.Task object at 0x7fac52553880>, 565: <__main__.Task object at 0x7fac52553730>, 566: <__main__.Task object at 0x7fac525536d0>, 567: <__main__.Task object at 0x7fac525537f0>, 568: <__main__.Task object at 0x7fac52553c10>, 569: <__main__.Task object at 0x7fac52552bf0>, 570: <__main__.Task object at 0x7fac52553cd0>, 571: <__main__.Task object at 0x7fac52553c70>, 572: <__main__.Task object at 0x7fac52552da0>, 573: <__main__.Task object at 0x7fac52552cb0>, 574: <__main__.Task object at 0x7fac52552b60>, 575: <__main__.Task object at 0x7fac52552a70>, 576: <__main__.Task object at 0x7fac52552bc0>, 577: <__main__.Task object at 0x7fac52552ad0>, 578: <__main__.Task object at 0x7fac52552c50>, 579: <__main__.Task object at 0x7fac52552a40>, 580: <__main__.Task object at 0x7fac52552560>, 581: <__main__.Task object at 0x7fac525524d0>, 582: <__main__.Task object at 0x7fac525522f0>, 583: <__main__.Task object at 0x7fac52552320>, 584: <__main__.Task object at 0x7fac52551390>, 585: <__main__.Task object at 0x7fac52551690>, 586: ...
#  Task: Task 501, Status: pending
#   Task: Task 502, Status: pending
#   Task: Task 503, Status: pending
#   Task: Task 504, Status: pending
#   Task: Task 505, Status: pending
#   Task: Task 506, Status: pending
#   Task: Task 507, Status: pending
#   Task: Task 508, Status: pending
#   Task: Task 509, Status: pending
#   Task: Task 510, Status: pending
#   Task: Task 511, Status: pending
#   Task: Task 512, Status: pending
#   Task: Task 513, Status: pending
#   Task: Task 514, Status: pending
#   Task: Task 515, Status: pending
#   Task: Task 516, Status: pending
#   Task: Task 517, Status: pending
#   Task: Task 518, Status: pending
#   Task: Task 519, Status: pending
#   Task: Task 520, Status: pending
#   Task: Task 521, Status: pending
#   Task: Task 522, Status: pending
#   Task: Task 523, Status: pending
#   Task: Task 524, Status: pending
#   Task: Task 525, Status: pending
#   Task: Task 526, Status: pending
#   Task: Task 527, Status: pending
#   Task: Task 528, Status: pending
#   Task: Task 529, Status: pending
#   Task: Task 530, Status: pending
#   Task: Task 531, Status: pending
#   Task: Task 532, Status: pending
#   Task: Task 533, Status: pending
#   Task: Task 534, Status: pending
#   Task: Task 535, Status: pending
#   Task: Task 536, Status: pending
#   Task: Task 537, Status: pending
#   Task: Task 538, Status: pending
#   Task: Task 539, Status: pending
#   Task: Task 540, Status: pending
#   Task: Task 541, Status: pending
#   Task: Task 542, Status: pending
#   Task: Task 543, Status: pending
#   Task: Task 544, Status: pending
#   Task: Task 545, Status: pending
#   Task: Task 546, Status: pending
#   Task: Task 547, Status: pending
#   Task: Task 548, Status: pending
#   Task: Task 549, Status: pending
#   Task: Task 550, Status: pending
#   Task: Task 551, Status: pending
#   Task: Task 552, Status: pending
#   Task: Task 553, Status: pending
#   Task: Task 554, Status: pending
#   Task: Task 555, Status: pending
#   Task: Task 556, Status: pending
#   Task: Task 557, Status: pending
#   Task: Task 558, Status: pending
#   Task: Task 559, Status: pending
#   Task: Task 560, Status: pending
#   Task: Task 561, Status: pending
#   Task: Task 562, Status: pending
#   Task: Task 563, Status: pending
#   Task: Task 564, Status: pending
#   Task: Task 565, Status: pending
#   Task: Task 566, Status: pending
#   Task: Task 567, Status: pending
#   Task: Task 568, Status: pending
#   Task: Task 569, Status: pending
#   Task: Task 570, Status: pending
#   Task: Task 571, Status: pending
#   Task: Task 572, Status: pending
#   Task: Task 573, Status: pending
#   Task: Task 574, Status: pending
#   Task: Task 575, Status: pending
#   Task: Task 576, Status: pending
#   Task: Task 577, Status: pending
#   Task: Task 578, Status: pending
#   Task: Task 579, Status: pending
#   Task: Task 580, Status: pending
#   Task: Task 581, Status: pending
#   Task: Task 582, Status: pending
#   Task: Task 583, Status: pending
#   Task: Task 584, Status: pending
#   Task: Task 585, Status: pending
#   Task: Task 586, Status: pending
#   Task: Task 587, Status: pending
#   Task: Task 588, Status: pending
#   Task: Task 589, Status: pending
#   Task: Task 590, Status: pending
#   Task: Task 591, Status: pending
#   Task: Task 592, Status: pending
#   Task: Task 593, Status: pending
#   Task: Task 594, Status: pending
#   Task: Task 595, Status: pending
#   Task: Task 596, Status: pending
#   Task: Task 597, Status: pending
#   Task: Task 598, Status: pending
#   Task: Task 599, Status: pending
#   Task: Task 600, Status: pending
#   Task: Task 601, Status: pending
#   Task: Task 602, Status: pending
#   Task: Task 603, Status: pending
#   Task: Task 604, Status: pending
#   Task: Task 605, Status: pending
#   Task: Task 606, Status: pending
#   Task: Task 607, Status: pending
#   Task: Task 608, Status: pending
#   Task: Task 609, Status: pending
#   Task: Task 610, Status: pending
#   Task: Task 611, Status: pending
#   Task: Task 612, Status: pending
#   Task: Task 613, Status: pending
#   Task: Task 614, Status: pending
#   Task: Task 615, Status: pending
#   Task: Task 616, Status: pending
#   Task: Task 617, Status: pending
#   Task: Task 618, Status: pending
#   Task: Task 619, Status: pending
#   Task: Task 620, Status: pending
#   Task: Task 621, Status: pending
#   Task: Task 622, Status: pending
#   Task: Task 623, Status: pending
#   Task: Task 624, Status: pending
#   Task: Task 625, Status: pending
#   Task: Task 626, Status: pending
#   Task: Task 627, Status: pending
#   Task: Task 628, Status: pending
#   Task: Task 629, Status: pending
#   Task: Task 630, Status: pending
#   Task: Task 631, Status: pending
#   Task: Task 632, Status: pending
#   Task: Task 633, Status: pending
#   Task: Task 634, Status: pending
#   Task: Task 635, Status: pending
#   Task: Task 636, Status: pending
#   Task: Task 637, Status: pending
#   Task: Task 638, Status: pending
#   Task: Task 639, Status: pending
#   Task: Task 640, Status: pending
#   Task: Task 641, Status: pending
#   Task: Task 642, Status: pending
#   Task: Task 643, Status: pending
#   Task: Task 644, Status: pending
#   Task: Task 645, Status: pending
#   Task: Task 646, Status: pending
#   Task: Task 647, Status: pending
#   Task: Task 648, Status: pending
#   Task: Task 649, Status: pending
#   Task: Task 650, Status: pending
#   Task: Task 651, Status: pending
#   Task: Task 652, Status: pending
#   Task: Task 653, Status: pending
#   Task: Task 654, Status: pending
#   Task: Task 655, Status: pending
#   Task: Task 656, Status: pending
#   Task: Task 657, Status: pending
#   Task: Task 658, Status: pending
#   Task: Task 659, Status: pending
#   Task: Task 660, Status: pending
#   Task: Task 661, Status: pending
#   Task: Task 662, Status: pending
#   Task: Task 663, Status: pending
#   Task: Task 664, Status: pending
#   Task: Task 665, Status: pending
#   Task: Task 666, Status: pending
#   Task: Task 667, Status: pending
#   Task: Task 668, Status: pending
#   Task: Task 669, Status: pending
#   Task: Task 670, Status: pending
#   Task: Task 671, Status: pending
#   Task: Task 672, Status: pending
#   Task: Task 673, Status: pending
#   Task: Task 674, Status: pending
#   Task: Task 675, Status: pending
#   Task: Task 676, Status: pending
#   Task: Task 677, Status: pending
#   Task: Task 678, Status: pending
#   Task: Task 679, Status: pending
#   Task: Task 680, Status: pending
#   Task: Task 681, Status: pending
#   Task: Task 682, Status: pending
#   Task: Task 683, Status: pending
#   Task: Task 684, Status: pending
#   Task: Task 685, Status: pending
#   Task: Task 686, Status: pending
#   Task: Task 687, Status: pending
#   Task: Task 688, Status: pending
#   Task: Task 689, Status: pending
#   Task: Task 690, Status: pending
#   Task: Task 691, Status: pending
#   Task: Task 692, Status: pending
#   Task: Task 693, Status: pending
#   Task: Task 694, Status: pending
#   Task: Task 695, Status: pending
#   Task: Task 696, Status: pending
#   Task: Task 697, Status: pending
#   Task: Task 698, Status: pending
#   Task: Task 699, Status: pending
#   Task: Task 700, Status: pending
#   Task: Task 701, Status: pending
#   Task: Task 702, Status: pending
#   Task: Task 703, Status: pending
#   Task: Task 704, Status: pending
#   Task: Task 705, Status: pending
#   Task: Task 706, Status: pending
#   Task: Task 707, Status: pending
#   Task: Task 708, Status: pending
#   Task: Task 709, Status: pending
#   Task: Task 710, Status: pending
#   Task: Task 711, Status: pending
#   Task: Task 712, Status: pending
#   Task: Task 713, Status: pending
#   Task: Task 714, Status: pending
#   Task: Task 715, Status: pending
#   Task: Task 716, Status: pending
#   Task: Task 717, Status: pending
#   Task: Task 718, Status: pending
#   Task: Task 719, Status: pending
#   Task: Task 720, Status: pending
#   Task: Task 721, Status: pending
#   Task: Task 722, Status: pending
#   Task: Task 723, Status: pending
#   Task: Task 724, Status: pending
#   Task: Task 725, Status: pending
#   Task: Task 726, Status: pending
#   Task: Task 727, Status: pending
#   Task: Task 728, Status: pending
#   Task: Task 729, Status: pending
#   Task: Task 730, Status: pending
#   Task: Task 731, Status: pending
#   Task: Task 732, Status: pending
#   Task: Task 733, Status: pending
#   Task: Task 734, Status: pending
#   Task: Task 735, Status: pending
#   Task: Task 736, Status: pending
#   Task: Task 737, Status: pending
#   Task: Task 738, Status: pending
#   Task: Task 739, Status: pending
#   Task: Task 740, Status: pending
#   Task: Task 741, Status: pending
#   Task: Task 742, Status: pending
#   Task: Task 743, Status: pending
#   Task: Task 744, Status: pending
#   Task: Task 745, Status: pending
#   Task: Task 746, Status: pending
#   Task: Task 747, Status: pending
#   Task: Task 748, Status: pending
#   Task: Task 749, Status: pending
#   Task: Task 750, Status: pending
#   Task: Task 751, Status: pending
#   Task: Task 752, Status: pending
#   Task: Task 753, Status: pending
#   Task: Task 754, Status: pending
#   Task: Task 755, Status: pending
#   Task: Task 756, Status: pending
#   Task: Task 757, Status: pending
#   Task: Task 758, Status: pending
#   Task: Task 759, Status: pending
#   Task: Task 760, Status: pending
#   Task: Task 761, Status: pending
#   Task: Task 762, Status: pending
#   Task: Task 763, Status: pending
#   Task: Task 764, Status: pending
#   Task: Task 765, Status: pending
#   Task: Task 766, Status: pending
#   Task: Task 767, Status: pending
#   Task: Task 768, Status: pending
#   Task: Task 769, Status: pending
#   Task: Task 770, Status: pending
#   Task: Task 771, Status: pending
#   Task: Task 772, Status: pending
#   Task: Task 773, Status: pending
#   Task: Task 774, Status: pending
#   Task: Task 775, Status: pending
#   Task: Task 776, Status: pending
#   Task: Task 777, Status: pending
#   Task: Task 778, Status: pending
#   Task: Task 779, Status: pending
#   Task: Task 780, Status: pending
#   Task: Task 781, Status: pending
#   Task: Task 782, Status: pending
#   Task: Task 783, Status: pending
#   Task: Task 784, Status: pending
#   Task: Task 785, Status: pending
#   Task: Task 786, Status: pending
#   Task: Task 787, Status: pending
#   Task: Task 788, Status: pending
#   Task: Task 789, Status: pending
#   Task: Task 790, Status: pending
#   Task: Task 791, Status: pending
#   Task: Task 792, Status: pending
#   Task: Task 793, Status: pending
#   Task: Task 794, Status: pending
#   Task: Task 795, Status: pending
#   Task: Task 796, Status: pending
#   Task: Task 797, Status: pending
#   Task: Task 798, Status: pending
#   Task: Task 799, Status: pending
#   Task: Task 800, Status: pending
#   Task: Task 801, Status: pending
#   Task: Task 802, Status: pending
#   Task: Task 803, Status: pending
#   Task: Task 804, Status: pending
#   Task: Task 805, Status: pending
#   Task: Task 806, Status: pending
#   Task: Task 807, Status: pending
#   Task: Task 808, Status: pending
#   Task: Task 809, Status: pending
#   Task: Task 810, Status: pending
#   Task: Task 811, Status: pending
#   Task: Task 812, Status: pending
#   Task: Task 813, Status: pending
#   Task: Task 814, Status: pending
#   Task: Task 815, Status: pending
#   Task: Task 816, Status: pending
#   Task: Task 817, Status: pending
#   Task: Task 818, Status: pending
#   Task: Task 819, Status: pending
#   Task: Task 820, Status: pending
#   Task: Task 821, Status: pending
#   Task: Task 822, Status: pending
#   Task: Task 823, Status: pending
#   Task: Task 824, Status: pending
#   Task: Task 825, Status: pending
#   Task: Task 826, Status: pending
#   Task: Task 827, Status: pending
#   Task: Task 828, Status: pending
#   Task: Task 829, Status: pending
#   Task: Task 830, Status: pending
#   Task: Task 831, Status: pending
#   Task: Task 832, Status: pending
#   Task: Task 833, Status: pending
#   Task: Task 834, Status: pending
#   Task: Task 835, Status: pending
#   Task: Task 836, Status: pending
#   Task: Task 837, Status: pending
#   Task: Task 838, Status: pending
#   Task: Task 839, Status: pending
#   Task: Task 840, Status: pending
#   Task: Task 841, Status: pending
#   Task: Task 842, Status: pending
#   Task: Task 843, Status: pending
#   Task: Task 844, Status: pending
#   Task: Task 845, Status: pending
#   Task: Task 846, Status: pending
#   Task: Task 847, Status: pending
#   Task: Task 848, Status: pending
#   Task: Task 849, Status: pending
#   Task: Task 850, Status: pending
#   Task: Task 851, Status: pending
#   Task: Task 852, Status: pending
#   Task: Task 853, Status: pending
#   Task: Task 854, Status: pending
#   Task: Task 855, Status: pending
#   Task: Task 856, Status: pending
#   Task: Task 857, Status: pending
#   Task: Task 858, Status: pending
#   Task: Task 859, Status: pending
#   Task: Task 860, Status: pending
#   Task: Task 861, Status: pending
#   Task: Task 862, Status: pending
#   Task: Task 863, Status: pending
#   Task: Task 864, Status: pending
#   Task: Task 865, Status: pending
#   Task: Task 866, Status: pending
#   Task: Task 867, Status: pending
#   Task: Task 868, Status: pending
#   Task: Task 869, Status: pending
#   Task: Task 870, Status: pending
#   Task: Task 871, Status: pending
#   Task: Task 872, Status: pending
#   Task: Task 873, Status: pending
#   Task: Task 874, Status: pending
#   Task: Task 875, Status: pending
#   Task: Task 876, Status: pending
#   Task: Task 877, Status: pending
#   Task: Task 878, Status: pending
#   Task: Task 879, Status: pending
#   Task: Task 880, Status: pending
#   Task: Task 881, Status: pending
#   Task: Task 882, Status: pending
#   Task: Task 883, Status: pending
#   Task: Task 884, Status: pending
#   Task: Task 885, Status: pending
#   Task: Task 886, Status: pending
#   Task: Task 887, Status: pending
#   Task: Task 888, Status: pending
#   Task: Task 889, Status: pending
#   Task: Task 890, Status: pending
#   Task: Task 891, Status: pending
#   Task: Task 892, Status: pending
#   Task: Task 893, Status: pending
#   Task: Task 894, Status: pending
#   Task: Task 895, Status: pending
#   Task: Task 896, Status: pending
#   Task: Task 897, Status: pending
#   Task: Task 898, Status: pending
#   Task: Task 899, Status: pending
#   Task: Task 900, Status: pending
#   Task: Task 901, Status: pending
#   Task: Task 902, Status: pending
#   Task: Task 903, Status: pending
#   Task: Task 904, Status: pending
#   Task: Task 905, Status: pending
#   Task: Task 906, Status: pending
#   Task: Task 907, Status: pending
#   Task: Task 908, Status: pending
#   Task: Task 909, Status: pending
#   Task: Task 910, Status: pending
#   Task: Task 911, Status: pending
#   Task: Task 912, Status: pending
#   Task: Task 913, Status: pending
#   Task: Task 914, Status: pending
#   Task: Task 915, Status: pending
#   Task: Task 916, Status: pending
#   Task: Task 917, Status: pending
#   Task: Task 918, Status: pending
#   Task: Task 919, Status: pending
#   Task: Task 920, Status: pending
#   Task: Task 921, Status: pending
#   Task: Task 922, Status: pending
#   Task: Task 923, Status: pending
#   Task: Task 924, Status: pending
#   Task: Task 925, Status: pending
#   Task: Task 926, Status: pending
#   Task: Task 927, Status: pending
#   Task: Task 928, Status: pending
#   Task: Task 929, Status: pending
#   Task: Task 930, Status: pending
#   Task: Task 931, Status: pending
#   Task: Task 932, Status: pending
#   Task: Task 933, Status: pending
#   Task: Task 934, Status: pending
#   Task: Task 935, Status: pending
#   Task: Task 936, Status: pending
#   Task: Task 937, Status: pending
#   Task: Task 938, Status: pending
#   Task: Task 939, Status: pending
#   Task: Task 940, Status: pending
#   Task: Task 941, Status: pending
#   Task: Task 942, Status: pending
#   Task: Task 943, Status: pending
#   Task: Task 944, Status: pending
#   Task: Task 945, Status: pending
#   Task: Task 946, Status: pending
#   Task: Task 947, Status: pending
#   Task: Task 948, Status: pending
#   Task: Task 949, Status: pending
#   Task: Task 950, Status: pending
#   Task: Task 951, Status: pending
#   Task: Task 952, Status: pending
#   Task: Task 953, Status: pending
#   Task: Task 954, Status: pending
#   Task: Task 955, Status: pending
#   Task: Task 956, Status: pending
#   Task: Task 957, Status: pending
#   Task: Task 958, Status: pending
#   Task: Task 959, Status: pending
#   Task: Task 960, Status: pending
#   Task: Task 961, Status: pending
#   Task: Task 962, Status: pending
#   Task: Task 963, Status: pending
#   Task: Task 964, Status: pending
#   Task: Task 965, Status: pending
#   Task: Task 966, Status: pending
#   Task: Task 967, Status: pending
#   Task: Task 968, Status: pending
#   Task: Task 969, Status: pending
#   Task: Task 970, Status: pending
#   Task: Task 971, Status: pending
#   Task: Task 972, Status: pending
#   Task: Task 973, Status: pending
#   Task: Task 974, Status: pending
#   Task: Task 975, Status: pending
#   Task: Task 976, Status: pending
#   Task: Task 977, Status: pending
#   Task: Task 978, Status: pending
#   Task: Task 979, Status: pending
#   Task: Task 980, Status: pending
#   Task: Task 981, Status: pending
#   Task: Task 982, Status: pending
#   Task: Task 983, Status: pending
#   Task: Task 984, Status: pending
#   Task: Task 985, Status: pending
#   Task: Task 986, Status: pending
#   Task: Task 987, Status: pending
#   Task: Task 988, Status: pending
#   Task: Task 989, Status: pending
#   Task: Task 990, Status: pending
#   Task: Task 991, Status: pending
#   Task: Task 992, Status: pending
#   Task: Task 993, Status: pending
#   Task: Task 994, Status: pending
#   Task: Task 995, Status: pending
#   Task: Task 996, Status: pending
#   Task: Task 997, Status: pending
#   Task: Task 998, Status: pending
#   Task: Task 999, Status: pending
#   Task: Task 1000, Status: pending
#   Task: Task 1, Status: completed
#   Task: Task 2, Status: completed
#   Task: Task 3, Status: completed
#   Task: Task 4, Status: completed
#   Task: Task 5, Status: completed
#   Task: Task 6, Status: completed
#   Task: Task 7, Status: completed
#   Task: Task 8, Status: completed
#   Task: Task 9, Status: completed
#   Task: Task 10, Status: completed
#   Task: Task 11, Status: completed
#   Task: Task 12, Status: completed
#   Task: Task 13, Status: completed
#   Task: Task 14, Status: completed
#   Task: Task 15, Status: completed
#   Task: Task 16, Status: completed
#   Task: Task 17, Status: completed
#   Task: Task 18, Status: completed
#   Task: Task 19, Status: completed
#   Task: Task 20, Status: completed
#   Task: Task 21, Status: completed
#   Task: Task 22, Status: completed
#   Task: Task 23, Status: completed
#   Task: Task 24, Status: completed
